# %% [markdown]
# - setosa -> 0
# - versicolor -> 1
# - virginica -> 2

# %%
from sklearn import preprocessing

labels = ['setosa', 'versicolor', 'virginica']

# %%
encoder = preprocessing.LabelEncoder()
encoder.fit(labels)

for i, item in enumerate(encoder.classes_):
    print(item, '=>', i)
# Out:
# setosa => 0
# versicolor => 1
# virginica => 2

# %%
print(encoder.classes_)
for i, item in enumerate(encoder.classes_):
    print(i, '=>', item)
# Out:
# ['setosa' 'versicolor' 'virginica']
# 0 => setosa
# 1 => versicolor
# 2 => virginica

# %%
more_labels = ['versicolor', 'versicolor', 'virginica', 'setosa', 'versicolor']
more_labels_encoded = encoder.transform(more_labels)

print('\nMore labels =', more_labels)
print('\nMore labels encoded =', list(more_labels_encoded))

for i, item in enumerate(encoder.classes_):
    print('\n',item, '+>', i)
# Out:
# More labels = ['versicolor', 'versicolor', 'virginica', 'setosa', 'versicolor']
#
# More labels encoded = [1, 1, 2, 0, 1]
#
#  setosa +> 0
#
#  versicolor +> 1
#
#  virginica +> 2

# %%
import pandas as pd

# %%
data = pd.read_csv('Churn_Modelling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
labels = data['Geography'].values
#labels_encoded = encoder.transform(labels)
##ValueError: y contains previously unseen labels: 'France'

#labels_encoded = encoder.fit_transform(labels)

for i, item in enumerate(encoder.classes_):
    print('\n',item,'=>',i,'\n')
# Out:
#  France => 0
#
#
#  Germany => 1
#
#
#  Spain => 2

# %%
#print(len(labels = data['Surname'].values))
labels = data['Surname'].value_counts()
len(labels)
# Out:
# 2932

# %%
#data['Surname'].value_counts()
labels = data['Surname'].values
#labels_encoded = encoder.transform(labels)
##ValueError: y contains previously unseen labels: 'France'

labels_encoded = encoder.fit_transform(labels)

for i, item in enumerate(encoder.classes_):
    print('\n',item,'=>',i,'\n')
# Out:
#  Abazu => 0
#
#
#  Abbie => 1
#
#
#  Abbott => 2
#
#
#  Abdullah => 3
#
#
#  Abdulov => 4
#
#
#  Abel => 5
#
#
#  Abernathy => 6
#
#
#  Abramov => 7
#
#
#  Abramova => 8
#
#
#  Abramovich => 9
#
#
#  Abramowitz => 10
#
#
#  Abrego => 11
#
#
#  Abron => 12
#
#
#  Achebe => 13
#
#
#  Adams => 14
#
#
#  Adamson => 15
#
#
#  Afamefula => 16
#
#
#  Afamefuna => 17
#
#
#  Afanasyev => 18
#
#
#  Afanasyeva => 19
#
#
#  Agafonova => 20
#
#
#  Aguirre => 21
#
#
#  Ah Mouy => 22
#
#
#  Ahern => 23
#
#
#  Ahmed => 24
#
#
#  Aiken => 25
#
#
#  Aikenhead => 26
#
#
#  Ainsworth => 27
#
#
#  Aitken => 28
#
#
#  Ajuluchukwu => 29
#
#
#  Akabueze => 30
#
#
#  Akeroyd => 31
#
#
#  Akhtar => 32
#
#
#  Akobundu => 33
#
#
#  Aksakova => 34
#
#
#  Aksenov => 35
#
#
#  Aksenova => 36
#
#
#  Aksyonov => 37
#
#
#  Aksyonova => 38
#
#
#  Akubundu => 39
#
#
#  Akudinobi => 40
#
#
#  Alaniz => 41
#
#
#  Alderete => 42
#
#
#  Aldrich => 43
#
#
#  Aldridge => 44
#
#
#  Aleksandrova => 45
#
#
#  Alekseeva => 46
#
# ...
